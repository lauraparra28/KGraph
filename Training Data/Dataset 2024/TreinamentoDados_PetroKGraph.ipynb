# %% [markdown]
# # Script de Geração de Perguntas
# Gerar perguntas a partir do Grafo de Conhecimento (PetroKGraph) e criar o contexto relevante para cada pergunta.
#
# To begin, we need to import the necessary modules and set up the environment variables.
#
# #### Install LangChain and Neo4j
#
# ```bash
# !pip install networkx
# !pip install node2vec
# !pip install rdflib
#
# !pip install openai
# !pip install langchain
# !pip install neo4j
# !pip install transformers
# ```

# %%
import os
import json
import torch
import sentence_transformers
import rdflib
import networkx as nx
from node2vec import Node2Vec

# %% [markdown]
# ### **✅ Carregar o PetroKGraph**

# %%
from rdflib import Graph, URIRef, Namespace, Literal

g = rdflib.Graph()
g.parse("C:\Projetos GIT\LangChain\PetroKGraph_update.rdf", format="xml") 

G = nx.Graph()

# Añadir nodos y aristas del grafo RDF al grafo de NetworkX
for subj, pred, obj in g:
   
    G.add_edge(str(subj), str(obj), label=str(pred))

# %%
# Imprimir nodos
print("Nodos del grafo:")
print(G.edges())

# %%
print(f"* * * * * * * * *")
# Numero de nodos, ejes del grafo y grado medio
nodos = G.number_of_nodes()
ejes = G.number_of_edges()
k = ejes*2/nodos
densidad = nx.density(G)
print(f"Grafo con {nodos} nodos, {ejes} ejes, densidad {densidad} y grado medio {k}")

# Grado de los nodos: el número de conexiones de cada nodo
nx.degree(G)
# Out:
# * * * * * * * * *
# Grafo con 2441 nodos, 4389 ejes, densidad 0.0014737980268769181 y grado medio 3.5960671855796806

# %%
# Imprimir nodos
print("Nodos del grafo:")
print(G.nodes())

# %%
print("\nAristas del grafo con etiquetas:")
for edge in G.edges(data=True):
    print(edge)

# %% [markdown]
# ### ✅ Verificar etiquetas del Grafo

# %%
def verificar_etiquetas(grafo):
  """
  Recorre el grafo y verifica si cada nodo tiene una etiqueta asociada.
  """
  nodos_sin_etiqueta = []
  for nodo in grafo.nodes:
    if not grafo.has_node(nodo):
      continue

    etiqueta = grafo.nodes[nodo].get("label", None)
    if not etiqueta:
      nodos_sin_etiqueta.append(nodo)

  return nodos_sin_etiqueta

grafo = G

nodos_sin_etiqueta = verificar_etiquetas(grafo)
if nodos_sin_etiqueta:
  print(f"Se encontraron {len(nodos_sin_etiqueta)} nodos sin etiqueta:")
  print(nodos_sin_etiqueta)
else:
  print("Todos los nodos tienen etiqueta.")

# %%
def verificar_etiquetas_con_etiqueta(grafo):
  """
  Recorre el grafo y verifica si cada nodo tiene una etiqueta asociada.
  Si un nodo tiene etiqueta, imprime el nodo y su etiqueta.
  """
  nodos_sin_etiqueta = verificar_etiquetas(grafo)
  if nodos_sin_etiqueta:
    print(f"Se encontraron {len(nodos_sin_etiqueta)} nodos sin etiqueta:")
    for nodo in nodos_sin_etiqueta:
      etiqueta = grafo.nodes[nodo].get("label", None)
      if etiqueta:
        print(f"- {nodo}: {etiqueta}")
  else:
    print("Todos los nodos tienen etiqueta.")

# Ejemplo de uso
grafo = G
# Agregue nodos al grafo...

verificar_etiquetas_con_etiqueta(grafo)
# Out:
# Se encontraron 1240 nodos sin etiqueta:

# %%
def verificar_etiquetas_manual(grafo):
  """
  Recorre el grafo manualmente y verifica si cada nodo tiene una etiqueta asociada.
  Si un nodo tiene etiqueta, imprime el nodo y su etiqueta.
  """
  for nodo in grafo.nodes:
    if not grafo.has_node(nodo):
      continue

    etiqueta = grafo.nodes[nodo].get("label", None)
    if etiqueta:
      print(f"- {nodo}: {etiqueta}")
    #else: print(f"No hay nodos con atributos tipo -label-")

grafo = G
verificar_etiquetas_manual(grafo)

# %%
def verificar_etiquetas_con_nx_get_node_attributes(grafo):
  """
  Recorre el grafo y verifica si cada nodo tiene una etiqueta asociada utilizando nx.get_node_attributes.
  Si un nodo tiene etiqueta, imprime el nodo y su etiqueta.
  """
  for nodo, atributos in nx.get_node_attributes(grafo, name='label').items():
    if "label" in atributos:
      print(f"- {nodo}: {atributos['label']}")
    else: 
      print(f"No hay nodos con atributos tipo -label-")

grafo = nx.Graph()
verificar_etiquetas_con_nx_get_node_attributes(grafo)

# %% [markdown]
# ### ✅ **Inspección de las Triplas**

# %% [markdown]
# Primero, inspeccionar las triplas para ver cuántos elementos contienen. al parecer las "triples" encontrados tienen una cantidad significativamente mayor de elementos de lo esperado, esto va en concordancia a lo estudiado del grafo, lo que indica que están representando algo más complejo, siendo que son descripciones más detalladas de entidades.

# %%
# Inspeccionar las triplas
for triple in G:
    print(triple)
    print(f"Number of elements in triple: {len(triple)}")
    if len(triple) <= 3:
        print("Found a non-triple element")
# Out:
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#EXTERNO_EST_FISICA_ROCHA_006
# Number of elements in triple: 98
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#geological_structure
# Number of elements in triple: 90
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_300
# Number of elements in triple: 87
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#basin
# Number of elements in triple: 75
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0279
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_281
# Number of elements in triple: 87
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#membro_000
# Number of elements in triple: 80
# http://www.w3.org/2002/07/owl#NamedIndividual
# Number of elements in triple: 45
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_012120
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0383
# Number of elements in triple: 88
# ESPADA
# Number of elements in triple: 6
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#lithostratigraphic_unit
# Number of elements in triple: 93
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_256
# Number of elements in triple: 87
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_021906
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_270
# Number of elements in triple: 87
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0861
# Number of elements in triple: 88
# R.PRETO
# Number of elements in triple: 7
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_117
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_116
# Number of elements in triple: 87
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_006789
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#inter_membro_005
# Number of elements in triple: 86
# Membro Mcg
# Number of elements in triple: 10
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#grupo_038
# Number of elements in triple: 79
# Grupo Bauru
# Number of elements in triple: 11
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#has_quality
# Number of elements in triple: 81
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#quality_of
# Number of elements in triple: 80
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_010893
# Number of elements in triple: 89
# N8276205b159746dabb3e5658444e5cad
# Number of elements in triple: 33
# http://www.w3.org/2002/07/owl#Restriction
# Number of elements in triple: 41
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#interval_meets
# Number of elements in triple: 84
# intervalo encontra
# Number of elements in triple: 18
# N2a4a697ed39f4c6a8601d93548d67f81
# Number of elements in triple: 33
# N20a2406b06ca41cd8da164ce402a8256
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#grupo_000
# Number of elements in triple: 79
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#marlstone
# Number of elements in triple: 79
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_207
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Middle_Cenomanian_Subage
# Number of elements in triple: 94
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#geological_time_interval
# Number of elements in triple: 94
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_259
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#conglomerate
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_080
# Number of elements in triple: 87
# BARREIRINHAS
# Number of elements in triple: 12
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#scree
# Number of elements in triple: 75
# http://www.w3.org/2002/07/owl#Class
# Number of elements in triple: 35
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_281
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#grupo_033
# Number of elements in triple: 79
# N73ed935ca5724173b54472144c999b96
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#crossed_by
# Number of elements in triple: 80
# Nd9371fd058b24e38872756ff1f2c3195
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#field
# Number of elements in triple: 75
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#generated_by
# Number of elements in triple: 82
# gerado por
# Number of elements in triple: 10
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_335
# Number of elements in triple: 82
# Formação Aliança
# Number of elements in triple: 16
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Neogene
# Number of elements in triple: 77
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#membro_070
# Number of elements in triple: 80
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#shale
# Number of elements in triple: 75
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_239
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#dolomite
# Number of elements in triple: 78
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_204
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#sandstone
# Number of elements in triple: 79
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Lower_Aptian_Subage_quality
# Number of elements in triple: 97
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#geological_age
# Number of elements in triple: 84
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Permian
# Number of elements in triple: 77
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_100
# Number of elements in triple: 87
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_012020
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_294
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_103
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Upper_Santonian_Subage_quality
# Number of elements in triple: 100
# Nac25373f3a5e48ac821c63f154b02aaf
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#membro_020
# Number of elements in triple: 80
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#membro_028
# Number of elements in triple: 80
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_056
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_122
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_266
# Number of elements in triple: 87
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#inter_membro_004
# Number of elements in triple: 86
# Membro Mcup
# Number of elements in triple: 11
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#TEFR_CD_TIPO_EST_FISICA_ROCHA_080
# Number of elements in triple: 103
# Chevron
# Number of elements in triple: 7
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_149
# Number of elements in triple: 82
# Nca65b3c96b9841f6a3d1a0d5a42fa633
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#grupo_036
# Number of elements in triple: 79
# Grupo Curuá
# Number of elements in triple: 11
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0468
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#membro_060
# Number of elements in triple: 80
# Mb. Carmópolis
# Number of elements in triple: 14
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#temporal_region
# Number of elements in triple: 85
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#occurrent
# Number of elements in triple: 79
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#TEFR_CD_TIPO_EST_FISICA_ROCHA_207
# Number of elements in triple: 103
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#UpperCretaceous
# Number of elements in triple: 85
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#has_participant
# Number of elements in triple: 85
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#grupo_032
# Number of elements in triple: 79
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#anthropogenic_material
# Number of elements in triple: 92
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#geological_object
# Number of elements in triple: 87
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#calciarenite
# Number of elements in triple: 82
# calcarenito
# Number of elements in triple: 11
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#inter_formacao_021
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Lower_Berriasian_Subage_quality
# Number of elements in triple: 101
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Albian
# Number of elements in triple: 76
# N6c656ab5b38d4bad8a3f8920171e3965
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#halite
# Number of elements in triple: 76
# halita
# Number of elements in triple: 6
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_279
# Number of elements in triple: 82
# Fm. Santana
# Number of elements in triple: 11
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_161
# Number of elements in triple: 82
# Formação Gramame
# Number of elements in triple: 16
# N3a4f7931103545209e90f9209833de97
# Number of elements in triple: 33
# N4503c22e1cb149cb91d3d35aca9c2680
# Number of elements in triple: 33
# N16fc0c433e894bce8ac5576d00f89c66
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Lower_Campanian_Subage_quality
# Number of elements in triple: 100
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#grupo_024
# Number of elements in triple: 79
# Gr. Massacará
# Number of elements in triple: 13
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#independent_continuant
# Number of elements in triple: 92
# Nb94025f775064e03aa72239123788a3d
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_275
# Number of elements in triple: 87
# BACIA DE SÃO FRANCISCO
# Number of elements in triple: 22
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#TEFR_CD_TIPO_EST_FISICA_ROCHA_006
# Number of elements in triple: 103
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#TEFR_CD_TIPO_EST_FISICA_ROCHA_028
# Number of elements in triple: 103
# N5bf9ce35089d42c09e764c91fc012d2a
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#location_of
# Number of elements in triple: 81
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0048
# Number of elements in triple: 88
# ARACAS
# Number of elements in triple: 6
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Alagoas_Age_quality_formacao_286
# Number of elements in triple: 102
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Alagoas_Age
# Number of elements in triple: 81
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_011894
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#well
# Number of elements in triple: 74
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_022451
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#membro_010
# Number of elements in triple: 80
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#gipsita
# Number of elements in triple: 77
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#breccia
# Number of elements in triple: 77
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#rock
# Number of elements in triple: 74
# Nd1a5888bed554666aed22b399cccbffe
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Thanetian_quality
# Number of elements in triple: 87
# N01f4fb802d4b4a738abdebe480e24f26
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Albian_quality_SD_000
# Number of elements in triple: 91
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Middle_Campanian_Subage_quality
# Number of elements in triple: 101
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#membro_078
# Number of elements in triple: 80
# Mb. Catu
# Number of elements in triple: 8
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#argillite
# Number of elements in triple: 79
# argilito siltico
# Number of elements in triple: 16
# N4d67244def374c45a8339a358b4331dd
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_230
# Number of elements in triple: 87
# N0ee1491ddc4c49f5a6c01844540d1ba5
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_236
# Number of elements in triple: 87
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0363
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_240
# Number of elements in triple: 87
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#silt
# Number of elements in triple: 74
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Pliensbachian
# Number of elements in triple: 83
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#generically_dependent_continuant
# Number of elements in triple: 102
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#specifically_dependent_continuant
# Number of elements in triple: 103
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#externo_textura_005
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#textura
# Number of elements in triple: 77
# Nde7ab646ad2b4c7bb5e22f49ed38334a
# Number of elements in triple: 33
# Nc234b6389eb641cf9faec97acb0f2847
# Number of elements in triple: 33
# Nf1d984aad5aa4c0b9819aed58bb3bae3
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#membro_025
# Number of elements in triple: 80
# Membro Gomo
# Number of elements in triple: 11
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_096
# Number of elements in triple: 82
# Membro Rio do Sul
# Number of elements in triple: 17
# Ncaea766f75014787a4fca9fa236941c0
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#rhyolite
# Number of elements in triple: 78
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_251
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_025125
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_096
# Number of elements in triple: 87
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#externo_textura_002
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#earth_material
# Number of elements in triple: 84
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#object_aggregate
# Number of elements in triple: 86
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#membro_050
# Number of elements in triple: 80
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0259
# Number of elements in triple: 88
# CASSARONGONGO
# Number of elements in triple: 13
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#membro_075
# Number of elements in triple: 80
# Membro Cuiabá Paulista
# Number of elements in triple: 22
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#phonolite
# Number of elements in triple: 79
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_344
# Number of elements in triple: 82
# Nfd197b8478ff43d991c7cd53e2f1a4b5
# Number of elements in triple: 33
# N6f3d6db5c87a402797ed4db7000f63a0
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_076
# Number of elements in triple: 87
# N262bc3d6ee024450b4d55fa49fd6456a
# Number of elements in triple: 33
# Formação Muribeca
# Number of elements in triple: 17
# Na99e56dbc99a4b3d8362a9f2464755fd
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#grupo_008
# Number of elements in triple: 79
# Grupo Espírito Santo
# Number of elements in triple: 20
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Upper_Maastrichtian_Subage
# Number of elements in triple: 96
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0082
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#TEFR_CD_TIPO_EST_FISICA_ROCHA_140
# Number of elements in triple: 103
# Filmes de Argila
# Number of elements in triple: 16
# Na034c7571a58439580dcfdb6e32a5298
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_030
# Number of elements in triple: 87
# N3d885d6c3437403eb90115db5c1fc147
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0634
# Number of elements in triple: 88
# LINGUADO
# Number of elements in triple: 8
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#pyroclastic_breccia
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_136
# Number of elements in triple: 82
# Formação Cabo
# Number of elements in triple: 13
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_183
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_233
# Number of elements in triple: 82
# Formação Corumbataí
# Number of elements in triple: 19
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Danian_quality
# Number of elements in triple: 84
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Lower_Toarcian_Subage
# Number of elements in triple: 91
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_256
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_153
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0419
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_254
# Number of elements in triple: 82
# folhelho siltico
# Number of elements in triple: 16
# Nc096512075534fba82685d305b64948a
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#membro_002
# Number of elements in triple: 80
# Mb. Triunfo
# Number of elements in triple: 11
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_295
# Number of elements in triple: 82
# Fm. Bananeiras
# Number of elements in triple: 14
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#is_concretized_as
# Number of elements in triple: 87
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_012983
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#gravel
# Number of elements in triple: 76
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#unconsolidated_earth_material
# Number of elements in triple: 99
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#TEFR_CD_TIPO_EST_FISICA_ROCHA_226
# Number of elements in triple: 103
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0936
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#role_of
# Number of elements in triple: 77
# http://www.w3.org/2002/07/owl#ObjectProperty
# Number of elements in triple: 44
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Upper_Albian_Subage
# Number of elements in triple: 89
# Nbf50f323769a44bc968c6cb7739b03d0
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0844
# Number of elements in triple: 88
# RIO ITAUNAS
# Number of elements in triple: 11
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#oil
# Number of elements in triple: 73
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#o&g_earth_fluid
# Number of elements in triple: 85
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_005498
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#located_in
# Number of elements in triple: 80
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0519
# Number of elements in triple: 88
# FURADO
# Number of elements in triple: 6
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0393
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0552
# Number of elements in triple: 88
# IRAI
# Number of elements in triple: 4
# Nf1fe5d8b69514a72aebe8fda065b21a3
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0533
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0403
# Number of elements in triple: 88
# N18f8e52ebe974b6785bc5c34d5710696
# Number of elements in triple: 33
# Ripples Unidirecionais
# Number of elements in triple: 22
# Nd06c1f81a40d4318954e746518f62794
# Number of elements in triple: 33
# N5dc56801f8c24416a1966f17cfe3b3e1
# Number of elements in triple: 33
# http://www.w3.org/2002/07/owl#IrreflexiveProperty
# Number of elements in triple: 49
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Dom_Joao_Age
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_232
# Number of elements in triple: 82
# localização de
# Number of elements in triple: 14
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0725
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#inter_formacao_002
# Number of elements in triple: 88
# Fm. Cabo Carvoeiro
# Number of elements in triple: 18
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0373
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#disposition
# Number of elements in triple: 81
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_200
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_060
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Priabonian_quality
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0065
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_193
# Number of elements in triple: 82
# Fm. Pirambóia
# Number of elements in triple: 13
# N0256ca4fad4742c4a8121ce4cda572db
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_034
# Number of elements in triple: 82
# Formação Maria Farinha
# Number of elements in triple: 22
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#inter_formacao_007
# Number of elements in triple: 88
# SÃ£o GiÃ£o
# Number of elements in triple: 10
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_381
# Number of elements in triple: 87
# PELOTAS
# Number of elements in triple: 7
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#immaterial_entity
# Number of elements in triple: 87
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#material_entity
# Number of elements in triple: 85
# N870e25da611846ec9f6c0f5f8e9e93c4
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#TEFR_CD_TIPO_EST_FISICA_ROCHA_224
# Number of elements in triple: 103
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Aratu_Age
# Number of elements in triple: 79
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#inter_formacao_012
# Number of elements in triple: 88
# FormaÃ§Ã£o Ratawi
# Number of elements in triple: 17
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Lower_Hauterivian_Subage
# Number of elements in triple: 94
# Nb635aaa3162e40daaa44233e306d7266
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#crosses
# Number of elements in triple: 77
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#inter_membro_008
# Number of elements in triple: 86
# Membro Cabo Blanco
# Number of elements in triple: 18
# DOM JOAO MAR
# Number of elements in triple: 12
# Ne1120784e96f43ef9221767ad4c0e96c
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0209
# Number of elements in triple: 88
# CAMACARI
# Number of elements in triple: 8
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0152
# Number of elements in triple: 88
# BONITO
# Number of elements in triple: 6
# Nd6b076bdc64d46a5bdacfaf967a97977
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Aratu_Age_quality
# Number of elements in triple: 87
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#interval_disjoint
# Number of elements in triple: 87
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#diamictite
# Number of elements in triple: 80
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Dom_Joao_Age_quality
# Number of elements in triple: 90
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Paleogene
# Number of elements in triple: 79
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#INTER_BACIA_011
# Number of elements in triple: 85
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#inter_formacao_016
# Number of elements in triple: 88
# Brushy Canion
# Number of elements in triple: 13
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0352
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#inter_formacao_005
# Number of elements in triple: 88
# Fm. Ãgua de Madeiros
# Number of elements in triple: 20
# Na1a16dd4d1b248bb87314c6b2dc7fe39
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#interval_finishes
# Number of elements in triple: 87
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#interval_in
# Number of elements in triple: 81
# N0f0be59aa5c54a4086de4af27ae0a5f9
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#grupo_001
# Number of elements in triple: 79
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#inter_formacao_023
# Number of elements in triple: 88
# Nc3dacdc1b9e44e159507da714295d0aa
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_236
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#TEFR_CD_TIPO_EST_FISICA_ROCHA_050
# Number of elements in triple: 103
# Bandamento
# Number of elements in triple: 10
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#one-dimensional_temporal_region
# Number of elements in triple: 101
# N6c6ef448c62b47b085def37698374cd2
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0682
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_210
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#diabase
# Number of elements in triple: 77
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#generically_depends_on
# Number of elements in triple: 92
# Mcg
# Number of elements in triple: 3
# Found a non-triple element
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_020
# Number of elements in triple: 87
# N1cf66e32f69d4e6cbcff4dd9a599d019
# Number of elements in triple: 33
# AMAZONAS
# Number of elements in triple: 8
# FZ.BELÉM (REC)
# Number of elements in triple: 14
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#hiloclastite
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0214
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#amphibolite
# Number of elements in triple: 81
# disposição
# Number of elements in triple: 10
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_010546
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_125
# Number of elements in triple: 82
# Fm. Rio Doce
# Number of elements in triple: 12
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#generic_earth_fluid
# Number of elements in triple: 89
# fluido geológico de O&G
# Number of elements in triple: 23
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_012838
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Rio_da_serra_Age
# Number of elements in triple: 86
# membro margas e calcÃ¡rios grumosos
# Number of elements in triple: 35
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_013
# Number of elements in triple: 82
# Fm. Sergi
# Number of elements in triple: 9
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_025010
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_021352
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#greenschist
# Number of elements in triple: 81
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#INTER_BACIA_021
# Number of elements in triple: 85
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2
# Number of elements in triple: 69
# http://www.w3.org/2002/07/owl#Ontology
# Number of elements in triple: 38
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_023044
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_286
# Number of elements in triple: 82
# Fm. Marizal
# Number of elements in triple: 11
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#reservoir
# Number of elements in triple: 79
# N7b5807968420463982d3a7ce0d77a26a
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#TEFR_CD_TIPO_EST_FISICA_ROCHA_045
# Number of elements in triple: 103
# Ndc82fe06d52a46feb0b21519af948234
# Number of elements in triple: 33
# JUBARTE
# Number of elements in triple: 7
# N426d8518d8c3459fae646d7fa4d64762
# Number of elements in triple: 33
# N74c65be49e9e43c6bd4c970538161407
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#source_rock
# Number of elements in triple: 81
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#petroleum_system_elements
# Number of elements in triple: 95
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_021346
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Cretaceous
# Number of elements in triple: 80
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#TEFR_CD_TIPO_EST_FISICA_ROCHA_126
# Number of elements in triple: 103
# Fm. Corumbataí
# Number of elements in triple: 14
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_250
# Number of elements in triple: 87
# Nf40c4ff1c1bc41ee8497db6f9b279cf6
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Alagoas_Age_quality_formacao_013
# Number of elements in triple: 102
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Alagoas_Age_quality
# Number of elements in triple: 89
# BACIA DE RECÔNCAVO
# Number of elements in triple: 18
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_024465
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_215
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#clay
# Number of elements in triple: 74
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_023048
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Upper_Albian_Subage_quality
# Number of elements in triple: 97
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_216
# Number of elements in triple: 82
# Formação Serraria
# Number of elements in triple: 17
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Neo-alagoas_Subage_quality
# Number of elements in triple: 96
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#laminito
# Number of elements in triple: 78
# laminito
# Number of elements in triple: 8
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Lower_Maastrichtian_Subage_quality
# Number of elements in triple: 104
# unidade geocronológica
# Number of elements in triple: 22
# N4954555ad4df4c79a5a9b1b59bde0473
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#geochronologic_age
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0118
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_059
# Number of elements in triple: 82
# Fm. Codó
# Number of elements in triple: 8
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Atokan_Age_quality
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_126
# Number of elements in triple: 82
# Formação Morro do Chaves
# Number of elements in triple: 24
# Membro Mucuri
# Number of elements in triple: 13
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0249
# Number of elements in triple: 88
# CARMOPOLIS
# Number of elements in triple: 10
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#has_age
# Number of elements in triple: 77
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_024505
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_110
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Rio_da_serra_Age_quality
# Number of elements in triple: 94
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#geological_process
# Number of elements in triple: 88
# N23897e8d338147dfb5ae68770b6e32ac
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_023072
# Number of elements in triple: 89
# GU-1-PA
# Number of elements in triple: 7
# http://www.w3.org/2004/02/skos/core#definition
# Number of elements in triple: 46
# http://www.w3.org/2002/07/owl#AnnotationProperty
# Number of elements in triple: 48
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_341
# Number of elements in triple: 82
# unidade litoestratigráfica
# Number of elements in triple: 26
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_004487
# Number of elements in triple: 89
# 7-DJ-695.BA
# Number of elements in triple: 11
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_220
# Number of elements in triple: 87
# TUCANO CENTRAL
# Number of elements in triple: 14
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_305
# Number of elements in triple: 87
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_050
# Number of elements in triple: 82
# Formação Macau
# Number of elements in triple: 14
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#silcrete
# Number of elements in triple: 78
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Jurassic_quality
# Number of elements in triple: 86
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Aptian_quality
# Number of elements in triple: 84
# Formação Itamaracá
# Number of elements in triple: 18
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_012097
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_023169
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Upper_Barremian_Subage
# Number of elements in triple: 92
# Fm. Rio de Contas
# Number of elements in triple: 17
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_131
# Number of elements in triple: 82
# Fm. Poção
# Number of elements in triple: 9
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0958
# Number of elements in triple: 88
# TAQUIPE
# Number of elements in triple: 7
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#textura_067
# Number of elements in triple: 81
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_006960
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_025253
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_260
# Number of elements in triple: 87
# N1e95b34802304d15b82d111b4f42ed8a
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#siltstone
# Number of elements in triple: 79
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0174
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_061
# Number of elements in triple: 82
# Fm. Pimenteiras
# Number of elements in triple: 15
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Albian_quality
# Number of elements in triple: 84
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_305
# Number of elements in triple: 82
# Formação Santa Brígida
# Number of elements in triple: 22
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#pyroclastic_rock
# Number of elements in triple: 86
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0916
# Number of elements in triple: 88
# SAO MIGUEL DOS CAMPOS
# Number of elements in triple: 21
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_022751
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_264
# Number of elements in triple: 82
# N17098163fd7047c4bc461438c5ac82b5
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#membro_058
# Number of elements in triple: 80
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0760
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_023073
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#sand
# Number of elements in triple: 74
# Nb026a692290146f68b241dba0d841634
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_053
# Number of elements in triple: 82
# Formação Missão Velha
# Number of elements in triple: 21
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Mesoriodaserra_Subage_quality
# Number of elements in triple: 99
# arenito conglomeratico
# Number of elements in triple: 22
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_012198
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Pliocene_quality_formacao_016
# Number of elements in triple: 99
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Pliocene
# Number of elements in triple: 78
# N5d249f75859e4f8c88aaeba9e7d0ac5f
# Number of elements in triple: 33
# N90e26c05998943558a272e32f38a94c3
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_260
# Number of elements in triple: 82
# Formação Batinga
# Number of elements in triple: 16
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#TEFR_CD_TIPO_EST_FISICA_ROCHA_055
# Number of elements in triple: 103
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_066
# Number of elements in triple: 87
# BACIA DE RIO DO PEIXE
# Number of elements in triple: 21
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Archean_quality
# Number of elements in triple: 85
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#interval_before
# Number of elements in triple: 85
# BACIA DE BARREIRINHAS
# Number of elements in triple: 21
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0444
# Number of elements in triple: 88
# FZ.CEDRO
# Number of elements in triple: 8
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#paraconglomerado
# Number of elements in triple: 86
# CUMURUXATIBA TERRA
# Number of elements in triple: 18
# N63a9c2f34c5643edacf543c37ae807ef
# Number of elements in triple: 33
# Nd608aa010ff8482a968fa6bbd8ac7dad
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0929
# Number of elements in triple: 88
# FZ.ALVORADA
# Number of elements in triple: 11
# BACIA DE PARANÁ
# Number of elements in triple: 15
# N4052384c622e44b0a6cd34de37d8305e
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_310
# Number of elements in triple: 87
# CURITIBA
# Number of elements in triple: 8
# N871ef8500a17495983020a5a999202f1
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_027
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_002
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0521
# Number of elements in triple: 88
# BACIA DE CEARÁ
# Number of elements in triple: 14
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Upper_Turonian_Subage_quality
# Number of elements in triple: 99
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#BASE_CD_BACIA_160
# Number of elements in triple: 87
# CEDRO
# Number of elements in triple: 5
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Aratu_Age_quality_formacao_153
# Number of elements in triple: 100
# geological age
# Number of elements in triple: 14
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_010831
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#inter_membro_006
# Number of elements in triple: 86
# Polvoeira
# Number of elements in triple: 9
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0128
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0631
# Number of elements in triple: 88
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#basanite
# Number of elements in triple: 78
# Grupo Massacará
# Number of elements in triple: 15
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Priabonian
# Number of elements in triple: 80
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#mudstone
# Number of elements in triple: 78
# mudstone
# Number of elements in triple: 8
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_007140
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_012116
# Number of elements in triple: 89
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formacao_016
# Number of elements in triple: 82
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#basalt
# Number of elements in triple: 76
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#LowerCretaceous
# Number of elements in triple: 85
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Carboniferous_quality_formacao_260
# Number of elements in triple: 104
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#textura_032
# Number of elements in triple: 81
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#textura_039
# Number of elements in triple: 81
# Zonada
# Number of elements in triple: 6
# N10f0e1404f28434c9c1c69e03c305776
# Number of elements in triple: 33
# N31a6a4d0cf4f4853b44178ce893b8074
# Number of elements in triple: 33
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#CAMP_CD_CAMPO_0880
# Number of elements in triple: 88
# R.URUCU
# Number of elements in triple: 7
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#TEFR_CD_TIPO_EST_FISICA_ROCHA_048
# ...
# CARMÓPOLIS SW
# Number of elements in triple: 13
# entidade material
# Number of elements in triple: 17
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Kazaniano
# Number of elements in triple: 79
# TUCANO SUL
# Number of elements in triple: 10
# DOM JOÃO
# Number of elements in triple: 8
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_023126
# Number of elements in triple: 89
# membro margas e calcÃ¡rios com Uptonia e Pentacrinus
# Number of elements in triple: 52
# SERGIPE TERRA
# Number of elements in triple: 13
# Fanerítica
# Number of elements in triple: 10
# intervalo disjunto
# Number of elements in triple: 18
# Formação Algodoais
# Number of elements in triple: 18
# FormaÃ§Ã£o Zu-bair
# Number of elements in triple: 18
# Formação Itaparica
# Number of elements in triple: 18
# Fm. Morro do Barro
# Number of elements in triple: 18
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#plutonic_rock
# Number of elements in triple: 83
# plutonica nao identificada
# Number of elements in triple: 26
# CAMORIM
# Number of elements in triple: 7
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Upper_Campanian_Subage_quality
# Number of elements in triple: 100
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Lower_Albian_Subage
# Number of elements in triple: 89
# geological object
# Number of elements in triple: 17
# Mb. Polvoeira
# Number of elements in triple: 13
# intervalo antes
# Number of elements in triple: 15
# immaterial entity
# Number of elements in triple: 17
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Arenig_Epoch
# Number of elements in triple: 82
# atravessa
# Number of elements in triple: 9
# Fm. Salvador
# Number of elements in triple: 12
# TUBARÃO
# Number of elements in triple: 7
# Fm. Itaípe
# Number of elements in triple: 10
# object
# Number of elements in triple: 6
# Fm. Santa Brígida
# Number of elements in triple: 17
# Falha
# Number of elements in triple: 5
# MARIMBÁ
# Number of elements in triple: 7
# Fm. Teresina
# Number of elements in triple: 12
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#water
# Number of elements in triple: 75
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Neo-Alagoas_Subage
# Number of elements in triple: 88
# 1BRSA453RN
# Number of elements in triple: 10
# Somatito Superior
# Number of elements in triple: 17
# Formação Açu
# Number of elements in triple: 12
# Fm. Estância
# Number of elements in triple: 12
# laminito liso
# Number of elements in triple: 13
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#TEFR_CD_TIPO_EST_FISICA_ROCHA_066
# Number of elements in triple: 103
# Fm. Serra Alta
# Number of elements in triple: 14
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Devonian
# Number of elements in triple: 78
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Meso-alagoas_Subage_quality
# Number of elements in triple: 97
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Valanginian
# Number of elements in triple: 81
# ALTO RODRIGUES
# Number of elements in triple: 14
# BACIA DE SÃO LUIZ
# Number of elements in triple: 17
# ÁGUA GRANDE
# Number of elements in triple: 11
# BACIA DE CAMAMU-ALMADA
# Number of elements in triple: 22
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Holocene
# Number of elements in triple: 78
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Santonian_quality
# Number of elements in triple: 87
# ALAGOAS MAR
# Number of elements in triple: 11
# GUAMARE SUDESTE
# Number of elements in triple: 15
# Fm. Hanifa
# Number of elements in triple: 10
# Fm. Abaiara
# Number of elements in triple: 11
# Gr. Santo Amaro
# Number of elements in triple: 15
# grainstone
# Number of elements in triple: 10
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Upper_Barremian_Subage_quality
# Number of elements in triple: 100
# N2c914f6727fe462c879e07fdfd130673
# Number of elements in triple: 33
# Fm. Macabu
# Number of elements in triple: 10
# Fm. Ubatuba
# Number of elements in triple: 11
# Formação Mariricu
# Number of elements in triple: 17
# bacia
# Number of elements in triple: 5
# PARGO
# Number of elements in triple: 5
# SANTOS
# Number of elements in triple: 6
# Membro Paraguaçu
# Number of elements in triple: 16
# BACIA DE IGUATU
# Number of elements in triple: 15
# CAMAMU TERRA
# Number of elements in triple: 12
# tem papel
# Number of elements in triple: 9
# quartzito
# Number of elements in triple: 9
# Flaser
# Number of elements in triple: 6
# Mb. Campo do Tenente
# Number of elements in triple: 20
# Formação Ipojuca
# Number of elements in triple: 16
# Formação Morro do Barro
# Number of elements in triple: 23
# MANATI
# Number of elements in triple: 6
# GUAMARÉ SUDESTE
# Number of elements in triple: 15
# FAZENDA ALVORADA
# Number of elements in triple: 16
# CURIMÃ
# Number of elements in triple: 6
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#cobbles
# Number of elements in triple: 77
# Fm. Exu
# Number of elements in triple: 7
# RIO PRETO
# Number of elements in triple: 9
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Permiano_quality
# Number of elements in triple: 86
# Formação Rio Doce
# Number of elements in triple: 17
# CACHALOTE
# Number of elements in triple: 9
# SERGIPE-ALAGOAS
# Number of elements in triple: 15
# Fm. Ponta Grossa
# Number of elements in triple: 16
# Fm. SÃ£o GiÃ£o
# Number of elements in triple: 14
# Fm. Penedo
# Number of elements in triple: 10
# Fm. Montejunto
# Number of elements in triple: 14
# constituído por
# Number of elements in triple: 15
# Gr. Passa Dois
# Number of elements in triple: 14
# intervalo sobrepõe
# Number of elements in triple: 18
# vulcanica nao identificada
# Number of elements in triple: 26
# PARNAÍBA
# Number of elements in triple: 8
# Formação Regência
# Number of elements in triple: 17
# região temporal
# Number of elements in triple: 15
# Fm. Paracuru
# Number of elements in triple: 12
# Acamadamento Lenticular
# Number of elements in triple: 23
# Fm. Calumbi
# Number of elements in triple: 11
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Lutetian
# Number of elements in triple: 78
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#formation
# Number of elements in triple: 79
# Formação Cabiúnas
# Number of elements in triple: 17
# Clivagem
# Number of elements in triple: 8
# Fm. Ipu
# Number of elements in triple: 7
# Fm. Ubarana
# Number of elements in triple: 11
# BACIA DE CAMPOS
# Number of elements in triple: 15
# Formação Salvador
# Number of elements in triple: 17
# CAMPOS MAR
# Number of elements in triple: 10
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Neoriodaserra_Subage
# Number of elements in triple: 90
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#evaporite
# Number of elements in triple: 79
# processo geológico
# Number of elements in triple: 18
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#coquina
# Number of elements in triple: 77
# Fm. Camboriú
# Number of elements in triple: 12
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Lower_Campanian_Subage
# Number of elements in triple: 92
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#LowerCretaceous_quality
# Number of elements in triple: 93
# idade geológica
# Number of elements in triple: 15
# SÃO M.DOS CAMPOS
# Number of elements in triple: 16
# FormaÃ§Ã£o CabaÃ§os
# Number of elements in triple: 19
# un. litoestratigráfica
# Number of elements in triple: 22
# Fm. Candeeiro
# Number of elements in triple: 13
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Meso-alagoas_Subage
# Number of elements in triple: 89
# intervalo em
# Number of elements in triple: 12
# campo
# Number of elements in triple: 5
# material antropogênico
# Number of elements in triple: 22
# Fm. Alagamar
# Number of elements in triple: 12
# coquina
# Number of elements in triple: 7
# Formação Cabeças
# Number of elements in triple: 16
# Fm. Missão Velha
# Number of elements in triple: 16
# Formação Cricaré
# Number of elements in triple: 16
# BACIA DE SERGIPE-ALAGOAS
# Number of elements in triple: 24
# Praia de Pedra Lisa
# Number of elements in triple: 19
# riolito
# Number of elements in triple: 7
# Fm. Algodoais
# Number of elements in triple: 13
# JATOBÁ
# Number of elements in triple: 6
# Mb. Cabo Blanco
# Number of elements in triple: 15
# Dobra
# Number of elements in triple: 5
# BACIA DE JEQUITINHONHA
# Number of elements in triple: 22
# CARMOPOLIS NOROESTE
# Number of elements in triple: 19
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Cenomanian_quality
# Number of elements in triple: 88
# Fm. Riachuelo
# Number of elements in triple: 13
# tem característica
# Number of elements in triple: 18
# ignimbrite
# Number of elements in triple: 10
# FormaÃ§Ã£o Brushy Canion
# Number of elements in triple: 24
# CARMOPOLIS SUDOESTE
# Number of elements in triple: 19
# BALEIA FRANCA
# Number of elements in triple: 13
# BICUDO
# Number of elements in triple: 6
# CUMURUXATIBA
# Number of elements in triple: 12
# Formação Pirarucu
# Number of elements in triple: 17
# intervalo inicia
# Number of elements in triple: 16
# Gr. Ilhas
# Number of elements in triple: 9
# Formação Monte Alegre
# Number of elements in triple: 21
# continuante genericamente dependente
# Number of elements in triple: 36
# Fm. Pendência
# Number of elements in triple: 13
# Formação Tibau
# Number of elements in triple: 14
# Formação Juruá
# Number of elements in triple: 14
# Fm. São Sebastião
# Number of elements in triple: 17
# Bokkeweld
# Number of elements in triple: 9
# Dômica
# Number of elements in triple: 6
# poço
# Number of elements in triple: 4
# Fm. Batinga
# Number of elements in triple: 11
# RIACHUELO
# Number of elements in triple: 9
# NAMORADO
# Number of elements in triple: 8
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Paleocene
# Number of elements in triple: 79
# ALMADA TERRA
# Number of elements in triple: 12
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#inter_formacao_024
# Number of elements in triple: 88
# Formação Estiva
# Number of elements in triple: 15
# Criptocristalina
# Number of elements in triple: 16
# Fm. Itajaí-Açu
# Number of elements in triple: 14
# MIRANGA
# Number of elements in triple: 7
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Middle_Albian_Subage_quality
# Number of elements in triple: 98
# 4BRSA685ES
# Number of elements in triple: 10
# Convoluta
# Number of elements in triple: 9
# gnaisse
# Number of elements in triple: 7
# Mb. Somatito Inferior
# Number of elements in triple: 21
# poÃ§o 1-PSB-13-MG
# Number of elements in triple: 17
# Fm. Itaparica
# Number of elements in triple: 13
# Grupo Nativo
# Number of elements in triple: 12
# Grupo Macaúbas
# Number of elements in triple: 14
# LIVRAMENTO
# Number of elements in triple: 10
# filito
# Number of elements in triple: 6
# Diyab
# Number of elements in triple: 5
# Fm. Brejo Santo
# Number of elements in triple: 15
# ESPÍRITO SANTO
# Number of elements in triple: 14
# Fm. Aliança
# Number of elements in triple: 11
# Fm. Caravelas
# Number of elements in triple: 13
# BRAGANCA-VIZEU
# Number of elements in triple: 14
# Formação Estância
# Number of elements in triple: 17
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Upper_Berriasian_Subage_quality
# Number of elements in triple: 101
# material artificial
# Number of elements in triple: 19
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Ordovician_quality
# Number of elements in triple: 88
# 1-RJS-209
# Number of elements in triple: 9
# Fm. Aracaré
# Number of elements in triple: 11
# Formação Nova Olinda
# Number of elements in triple: 20
# Fm. Rio Bonito
# Number of elements in triple: 14
# intervalo termina
# Number of elements in triple: 17
# Discordância
# Number of elements in triple: 12
# característica de
# Number of elements in triple: 17
# calcario
# Number of elements in triple: 8
# continuante
# Number of elements in triple: 11
# object aggregate
# Number of elements in triple: 16
# ESPÍRITO SANTO TERRA
# Number of elements in triple: 20
# rocha vulcanoclastica
# Number of elements in triple: 21
# 1BRSA452RN
# Number of elements in triple: 10
# BRAGANCA VIZEU
# Number of elements in triple: 14
# Corte e Preenchimento
# Number of elements in triple: 21
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#POCO_CD_POCO_002878
# Number of elements in triple: 89
# fluido da terra
# Number of elements in triple: 15
# Gr. São Bento
# Number of elements in triple: 13
# independent continuant
# Number of elements in triple: 22
# disposition
# Number of elements in triple: 11
# Fm. Candeias
# Number of elements in triple: 12
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Eoburacica_Subage
# Number of elements in triple: 87
# Contato Erosivo
# Number of elements in triple: 15
# Membro Tarabai
# Number of elements in triple: 14
# UBARANA
# Number of elements in triple: 7
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#inter_formacao_017
# Number of elements in triple: 88
# CC 2
# Number of elements in triple: 4
# R.PRETO SUDESTE
# Number of elements in triple: 15
# packstone
# Number of elements in triple: 9
# ARARIPE
# Number of elements in triple: 7
# BACIA DE TUCANO CENTRAL
# Number of elements in triple: 23
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Mississippian_quality
# Number of elements in triple: 91
# objeto geológico
# Number of elements in triple: 16
# Mb. Mucuri
# Number of elements in triple: 10
# BACIA DE ARARIPE
# Number of elements in triple: 16
# Cabo Carvoeiro
# Number of elements in triple: 14
# SERNAMBI
# Number of elements in triple: 8
# arenito argiloso
# Number of elements in triple: 16
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#Neoproterozoic_quality
# Number of elements in triple: 92
# SIRIRIZINHO SUL
# Number of elements in triple: 15
# BACIA DE ITABORAÍ
# Number of elements in triple: 17
# intervalo contém
# Number of elements in triple: 16
# ALAGOAS TERRA
# Number of elements in triple: 13
# Mb. Mcup
# Number of elements in triple: 8
# Fm. Campo Mourão
# Number of elements in triple: 16
# Fm. Tibau
# Number of elements in triple: 9
# ILHA DA CAÇUMBA
# Number of elements in triple: 15
# FormaÃ§Ã£o Lemede
# Number of elements in triple: 17
# Formação Rio de Contas
# Number of elements in triple: 22
# Mud Couplet (pares de argila)
# Number of elements in triple: 29
# Formação Maceió
# Number of elements in triple: 15
# argilito carbonatico
# Number of elements in triple: 20
# idade de
# Number of elements in triple: 8
# Grupo São Bento
# Number of elements in triple: 15
# Fm. Coqueiros
# Number of elements in triple: 13
# Fm. Zu-bair
# Number of elements in triple: 11
# Formação Taciba
# Number of elements in triple: 15
# Fm. Diyab
# Number of elements in triple: 9
# Laminação
# Number of elements in triple: 9
# 1SPS 0036 SP
# Number of elements in triple: 12
# Mb. Paraguaçu
# Number of elements in triple: 13
# argilito arenoso
# Number of elements in triple: 16
# entidade imaterial
# Number of elements in triple: 18
# Formação Codó
# Number of elements in triple: 13
# Formação Alagamar
# Number of elements in triple: 17
# brecha
# Number of elements in triple: 6
# Formação Itaituba
# Number of elements in triple: 17
# SÃO SEBASTIÃO
# Number of elements in triple: 13
# carvao
# Number of elements in triple: 6
# PERNAMBUCO-PARAÍBA
# Number of elements in triple: 18
# http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#INTER_BACIA_013
# Number of elements in triple: 85
# material geológico
# Number of elements in triple: 18
# Fm. Itaim
# Number of elements in triple: 9
# Membro CC 1
# Number of elements in triple: 11
# Mb. CC 2
# Number of elements in triple: 8
# Formação São Sebastião
# Number of elements in triple: 22
# depende genericamente de
# Number of elements in triple: 24
# Mb. Somatito Superior
# Number of elements in triple: 21
# SIRIRIZINHO W
# Number of elements in triple: 13
# RECÔNCAVO TERRA
# Number of elements in triple: 15
# participa de
# Number of elements in triple: 12
# Fm. Algodões
# Number of elements in triple: 12
# Formação Barra de Itiúba
# Number of elements in triple: 24
# ALTO DO RODRIGUES
# Number of elements in triple: 17
# Fm. Lagoa Azul
# Number of elements in triple: 14
# Laminação Convoluta
# Number of elements in triple: 19
# RIO DO PEIXE
# Number of elements in triple: 12
# Vale das Fontes
# Number of elements in triple: 15

# %% [markdown]
# Las "triplas" encontradas contienen descripciones más detalladas de entidades, descartar estos elementos resultaría en la pérdida de datos, entonces se adaptará el código para manejar este caso adecuadamente. Una forma de abordar esto es manejar triplas con un número variable de elementos. En lugar de asumir que cada triple tiene exactamente tres elementos.

# %% [markdown]
# ### ✅ **Consultar o PetroKGraph atualizado para obter informação relevante**

# %%
from rdflib import Graph, URIRef, Namespace, Literal

fields = {}
basins = {}
wells  = {}
formations = {}
for s, p, o in g:
    if isinstance(s, URIRef) and "CAMP_CD_CAMPO" in s:
        campo_id = s.split("#")[1]
        if campo_id not in fields:
            fields[campo_id] = {"types": [], "located_in": [], "labels": [], "related": []}
        if "type" in p:
            fields[campo_id]["types"].append(o)
        elif "located_in" in p:
            fields[campo_id]["located_in"].append(o)
        elif "label" in p:
            fields[campo_id]["labels"].append(str(o))
        else:
            fields[campo_id]["related"].append((p, o))

    if isinstance(s, URIRef) and "BASE_CD_BACIA" in s:
        bacia_id = s.split("#")[1]
        if bacia_id not in basins:
            basins[bacia_id] = {"types": [], "located_in": [], "labels": []}
        if "type" in p:
            basins[bacia_id]["types"].append(o)
        elif "located_in" in p:
            basins[bacia_id]["located_in"].append(o)
        elif "label" in p:
            basins[bacia_id]["labels"].append(str(o))
            
    if isinstance(s, URIRef) and "POCO_CD_POCO" in s:
        poco_id = s.split("#")[1]
        if poco_id not in wells:
            wells[poco_id] = {"types": [], "located_in": [], "labels": [], "crosses": []}
        if "type" in p:
            wells[poco_id]["types"].append(o)
        elif "located_in" in p:
            wells[poco_id]["located_in"].append(o)
        elif "crosses" in p:
            wells[poco_id]["crosses"].append(str(o))
        elif "label" in p:
            wells[poco_id]["labels"].append(str(o))

    if isinstance(s, URIRef) and "formacao" in s:
        unidade_lito_id = s.split("#")[1]
        if unidade_lito_id not in formations:
            formations[unidade_lito_id] = {"types": [], "located_in": [], "has_age": [], "part_of": [], "constituted_by": [], "crosses": [],  "labels": []}
        if "type" in p:
            formations[unidade_lito_id]["types"].append(o)
        elif "located_in" in p:
            formations[unidade_lito_id]["located_in"].append(str(o))  
        elif "constituted_by" in p:
            formations[unidade_lito_id]["constituted_by"].append(o) 
        elif "has_age" in p:
            formations[unidade_lito_id]["has_age"].append(str(o))  
        elif "part_of" in p:
            formations[unidade_lito_id]["part_of"].append(o)   
        
        elif "crosses" in p:
            formations[unidade_lito_id]["crosses"].append(str(o))
        elif "label" in p:
            formations[unidade_lito_id]["labels"].append(str(o))
          

    if isinstance(s, URIRef) and "grupo" in s:
        unidade_lito_id = s.split("#")[1]
        if unidade_lito_id not in formations:
            formations[unidade_lito_id] = {"types": [], "located_in": [], "has_age": [], "part_of": [], "constituted_by": [], "crosses": [],  "labels": []}
        if "type" in p:
            formations[unidade_lito_id]["types"].append(o)
        elif "located_in" in p:
            formations[unidade_lito_id]["located_in"].append(str(o))  
        elif "constituted_by" in p:
            formations[unidade_lito_id]["constituted_by"].append(o) 
        elif "has_age" in p:
            formations[unidade_lito_id]["has_age"].append(str(o))  
        elif "part_of" in p:
            formations[unidade_lito_id]["part_of"].append(o)   
        elif "crosses" in p:
            formations[unidade_lito_id]["crosses"].append(str(o))
        elif "label" in p:
            formations[unidade_lito_id]["labels"].append(str(o))
          

    if isinstance(s, URIRef) and "membro" in s:
        unidade_lito_id = s.split("#")[1]
        if unidade_lito_id not in formations:
            formations[unidade_lito_id] = {"types": [], "located_in": [], "has_age": [], "part_of": [], "constituted_by": [], "crosses": [],  "labels": [] }
        if "type" in p:
            formations[unidade_lito_id]["types"].append(o)
        elif "located_in" in p:
            formations[unidade_lito_id]["located_in"].append(str(o))  
        elif "constituted_by" in p:
            formations[unidade_lito_id]["constituted_by"].append(o) 
        elif "has_age" in p:
            formations[unidade_lito_id]["has_age"].append(str(o))  
        elif "part_of" in p:
            formations[unidade_lito_id]["part_of"].append(o)   
        elif "crosses" in p:
            formations[unidade_lito_id]["crosses"].append(str(o))
        elif "label" in p:
            formations[unidade_lito_id]["labels"].append(str(o))

# %% [markdown]
# ####  ✅ Corroborar informação extraida

# %%
# Formações extraídos
for forma, info in formations.items():
        print(f"** Unidade Litoestretigrafica: {forma}")
        print(f"  Parte de: {info['part_of']}")
        print(f"  Constituted  by: {info['constituted_by']}")
        print(f"  Crosses  by: {info['crosses']}")
        print(f"  Label: {info['labels']}")
        print(f"  Tem idade: {info['has_age']}")

# %%
# Campos extraídos
for campo, info in fields.items():
    print(f"Campo: {campo}")
    #print(f"  Tipos: {info['types']}")
    print(f"  Located in: {info['located_in']}")
    print(f"  Label: {info['labels']}")

# %%
# Bacias extraídos
for well, info in wells.items():
    print(f"Bacia: {well}")
    #print(f"  Tipos: {info['types']}")
    print(f"  Nombre del poço: {info['labels']}")
    print(f"  El poço atravessa: {info['labels']}")

# %% [markdown]
# ### 🔎 **Gerar as perguntas baseado no PetroKGraph** ✅ OK

# %%
namespace_base = rdflib.Namespace("http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#")
rdfs = Namespace("http://www.w3.org/2000/01/rdf-schema#")
rdf= Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")

def gerar_perguntas(g):
    questions = []
    for campo, info in fields.items():
        if info["located_in"]:
            location = info["located_in"][0].split("#")[1]
            campo_name = info["labels"][0] if info["labels"] else campo
            location_name = g.value(URIRef(f"http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#{location}"), rdfs.label)
            questions.append({
                "question": f"Onde está localizado o campo {campo_name}?",
                "answer": str(location_name),
                "context": f"O campo {campo_name} está localizado na bacia {location_name}."
            })

    for well, info in wells.items():
        if info["located_in"]:
            location = info["located_in"][0].split("#")[1]
            well_name = info["labels"][0] if info["labels"] else well
            location_name = g.value(URIRef(f"http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#{location}"), rdfs.label)
            questions.append({
                "question": f"Onde está localizado o poço {well_name}?",
                "answer": str(location_name),
                "context": f"O poço {well_name} está localizado na bacia {location_name}."
            })

    for well, info in wells.items():
        if info["crosses"]:
            cross_by = info["crosses"][0].split("#")[1]
            well_name = info["labels"][0] if info["labels"] else well
            cross_by_name = g.value(URIRef(f"http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#{cross_by}"), rdfs.label)
            questions.append({
                "question": f"Onde atraavessa o poço {well_name}?",
                "answer": str(cross_by_name),
                "context": f"O poço {well_name} atravessa {cross_by_name}."
            })

    for formacoes, info in formations.items():
        if info["constituted_by"]:
            constituted_by_names = []
            formation_name = info["labels"][0] if info["labels"] else formacoes

            # constituted_by_name = g.value(URIRef(f"http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#{constituted_by}"), rdfs.label)
            
            for material in info["constituted_by"]:
                material_id = material.split("#")[1]
                material_name = g.value(URIRef(f"http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#{material_id}"), rdfs.label)
                if material_name:
                    constituted_by_names.append(str(material_name))
        
            if constituted_by_names:
                constituted_by_materials = ", ".join(constituted_by_names)
                questions.append({
                    "question": f"Qual é o material da terra que está constituida a formação/grupo/membro {formation_name}?",
                    "answer": str(constituted_by_materials),
                    "context": f"A formação/grupo/membro {formation_name} está constituida por {constituted_by_materials}."
                })

    for formacoes, info in formations.items():
        if info["part_of"]:
            part_of = info["part_of"][0].split("#")[1]
            formation_name = info["labels"][0] if info["labels"] else formacoes
            part_of_name = g.value(URIRef(f"http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#{part_of}"), rdfs.label)
            questions.append({
                "question": f"Qual é a entidade que faz parte de {formation_name}?",
                "answer": str(part_of_name),
                "context": f"A formação/grupo/membro {formation_name} faz parte de {part_of_name}."
            })

    for formacoes, info in formations.items():
        if info["has_age"]:
            has_age = info["has_age"][0].split("#")[1]
            
            formation_name = info["labels"][0] if info["labels"] else formacoes
            
            has_age_name_unit = g.value(URIRef(f"http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#{has_age}"), rdf.type)
            #print (has_age_name_unit)
            has_age_name = list(g.objects(URIRef(f"{has_age_name_unit}"), rdfs.label))[2]
            #print (has_age_name)
            questions.append({
                "question": f"Qual é a idade geológica de {formation_name}?",
                "answer": str(has_age_name),
                "context": f"A idade geológica de {formation_name} é {has_age_name}."
            })

    for formacoes, info in formations.items():
        
        if info["located_in"]:
            location = info["located_in"][0].split("#")[1]
            if location != "basin" : 
                formation_name = info["labels"][0] if info["labels"] else formacoes
                location_name = g.value(URIRef(f"http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#{location}"), rdfs.label)
                #print (f"{formation_name}  ---> {location_name}")
                questions.append({
                    "question": f"Qual é a localização de {formation_name}?",
                    "answer": str(location_name),
                    "context": f"A {formation_name} está localizada na bacia {location_name}."
                })

    query = """
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX ont: <http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#>

    SELECT ?field (COUNT(?well) as ?pozos)
    WHERE {
    # ?well rdf:type ont:well .
    # ?field rdf:type ont:field .
    # ?well ont:located_in ?field .
    }
    GROUP BY ?field
    """

    results = g.query(query)

    for row in results:
        campo_uri = row.field
        count = row.pozos.toPython()  # Convertir Literal a un tipo Python nativo
        campo_name = g.value(campo_uri, rdfs.label)

        questions.append({
            "question": f"¿Quantos poços existem no campo {campo_name}?",
            "answer": str(count),
            "context": f"No campo {campo_name} existem no total {count} poços."
        })
                    
    return questions

# %%
namespace_base = rdflib.Namespace("http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#")
rdfs = Namespace("http://www.w3.org/2000/01/rdf-schema#")
rdf= Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")

def gerar_perguntas(g):
    questions = []
    for campo, info in fields.items():
        if info["located_in"]:
            location = info["located_in"][0].split("#")[1]
            campo_name = info["labels"][0] if info["labels"] else campo
            location_name = g.value(URIRef(f"http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#{location}"), rdfs.label)
            questions.append({
                "question": f"Onde está localizado o campo {campo_name}?",
                "answer": str(location_name),
                "context": f"O campo {campo_name} está localizado na bacia {location_name}."
            })

    for well, info in wells.items():
        if info["located_in"]:
            location = info["located_in"][0].split("#")[1]
            well_name = info["labels"][0] if info["labels"] else well
            location_name = g.value(URIRef(f"http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#{location}"), rdfs.label)
            questions.append({
                "question": f"Onde está localizado o poço {well_name}?",
                "answer": str(location_name),
                "context": f"O poço {well_name} está localizado na bacia {location_name}."
            })

    for well, info in wells.items():
        if info["crosses"]:
            cross_by = info["crosses"][0].split("#")[1]
            well_name = info["labels"][0] if info["labels"] else well
            cross_by_name = g.value(URIRef(f"http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#{cross_by}"), rdfs.label)
            questions.append({
                "question": f"Onde atraavessa o poço {well_name}?",
                "answer": str(cross_by_name),
                "context": f"O poço {well_name} atravessa {cross_by_name}."
            })

    for formacoes, info in formations.items():
        if info["constituted_by"]:
            constituted_by_names = []
            formation_name = info["labels"][0] if info["labels"] else formacoes

            # constituted_by_name = g.value(URIRef(f"http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#{constituted_by}"), rdfs.label)
            
            for material in info["constituted_by"]:
                material_id = material.split("#")[1]
                material_name = g.value(URIRef(f"http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#{material_id}"), rdfs.label)
                if material_name:
                    constituted_by_names.append(str(material_name))
        
            if constituted_by_names:
                constituted_by_materials = ", ".join(constituted_by_names)
                questions.append({
                    "question": f"Qual é o material da terra que está constituida a formação/grupo/membro {formation_name}?",
                    "answer": str(constituted_by_materials),
                    "context": f"A formação/grupo/membro {formation_name} está constituida por {constituted_by_materials}."
                })

    for formacoes, info in formations.items():
        if info["part_of"]:
            part_of = info["part_of"][0].split("#")[1]
            formation_name = info["labels"][0] if info["labels"] else formacoes
            part_of_name = g.value(URIRef(f"http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#{part_of}"), rdfs.label)
            questions.append({
                "question": f"Qual é a entidade que faz parte de {formation_name}?",
                "answer": str(part_of_name),
                "context": f"A formação/grupo/membro {formation_name} faz parte de {part_of_name}."
            })

    for formacoes, info in formations.items():
        if info["has_age"]:
            has_age = info["has_age"][0].split("#")[1]
            
            formation_name = info["labels"][0] if info["labels"] else formacoes
            
            has_age_name_unit = g.value(URIRef(f"http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#{has_age}"), rdf.type)
            #print (has_age_name_unit)
            has_age_name = list(g.objects(URIRef(f"{has_age_name_unit}"), rdfs.label))[2]
            #print (has_age_name)
            questions.append({
                "question": f"Qual é a idade geológica de {formation_name}?",
                "answer": str(has_age_name),
                "context": f"A idade geológica de {formation_name} é {has_age_name}."
            })

    for formacoes, info in formations.items():
        
        if info["located_in"]:
            location = info["located_in"][0].split("#")[1]
            if location != "basin" : 
                formation_name = info["labels"][0] if info["labels"] else formacoes
                location_name = g.value(URIRef(f"http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#{location}"), rdfs.label)
                #print (f"{formation_name}  ---> {location_name}")
                questions.append({
                    "question": f"Qual é a localização de {formation_name}?",
                    "answer": str(location_name),
                    "context": f"A {formation_name} está localizada na bacia {location_name}."
                })

    query = """
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX ont: <http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#>

    SELECT ?field (COUNT(?well) as ?pozos)
    WHERE {
    # ?well rdf:type ont:well .
    # ?field rdf:type ont:field .
    # ?well ont:located_in ?field .
    }
    GROUP BY ?field
    """

    results = g.query(query)

    for row in results:
        campo_uri = row.field
        count = row.pozos.toPython()  # Convertir Literal a un tipo Python nativo
        campo_name = g.value(campo_uri, rdfs.label)

        questions.append({
            "question": f"¿Quantos poços existem no campo {campo_name}?",
            "answer": str(count),
            "context": f"No campo {campo_name} existem no total {count} poços."
        })
                    
    return questions

# %% [markdown]
# #### ✅**Guardar as perguntas num arquivo JSON**

# %%
# Gerar os pares pergunta-resposta
dados_treinamento = gerar_perguntas(g)

with open('dataset_perguntas_respostas_update.json', 'w', encoding='utf-8') as file:
    json.dump(dados_treinamento, file, ensure_ascii=False, indent=4)
